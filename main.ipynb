# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import json,os

# %%
data_folfer = 'flink_metric_data_new/'
with open(f"{data_folfer}1dh1e3d93h944idh991i576e48917264_13604_129570_read_records_per_second.json") as f:
    data = json.load(f)

# %%
#test
df = pd.DataFrame(data['datapoints'])
df.drop('unit',axis=1,inplace=True)
df.head()
# Out:
#    average      timestamp
# 0    50.22  1541174400000
# 1    54.04  1541174700000
# 2    60.96  1541175000000
# 3    33.19  1541175300000
# 4    33.30  1541175600000

# %%
def plotMovingAverage(series, n):
    rolling_mean = series.rolling(window=n).mean()
    plt.figure(figsize=(15,5))
    #plt.title("Moving average\n window size = {}".format(n))
    plt.plot(rolling_mean, "g", label="Rolling mean trend")

    plt.plot(dataset[n:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
#df.set_index('timestamp')
df.set_index('timestamp').plot()
plotMovingAverage(df.set_index('timestamp'),24)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ee7a5e91af7b> in <module>
#       1 #df.set_index('timestamp')
#       2 df.set_index('timestamp').plot()
# ----> 3 plotMovingAverage(df.set_index('timestamp'),24)
#
# <ipython-input-16-71249a889682> in plotMovingAverage(series, n)
#       5     plt.plot(rolling_mean, "g", label="Rolling mean trend")
#       6
# ----> 7     plt.plot(dataset[n:], label="Actual values")
#       8     plt.legend(loc="upper left")
#       9     plt.grid(True)
#
# NameError: name 'dataset' is not defined
